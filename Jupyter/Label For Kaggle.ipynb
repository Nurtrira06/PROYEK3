# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
diagnosis = df['diagnosis']
diagnosis.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
df_diagnosis = pd.DataFrame(data=diagnosis)
df_diagnosis
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
df_diagnosis.to_excel("df_diagnosis.xlsx")
# Out:
# <ipython-input-5-f30166e8846f>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   df_diagnosis.to_excel("df_diagnosis.xlsx")

# %%
df = pd.read_excel('df_diagnosis.xlsx')
df.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
#ubah data kategorik  // memanipulasi data
df['diagnosis'].replace(['M', 'B'], 
                               ['Tumor Ganas (Terdeteksi Kanker)', 
                                'Tumor Jinak (Tidak Terdeteksi Kanker)'], 
                               inplace=True)
df.head()
# Out:
#                          diagnosis
# 0  Tumor Ganas (Terdeteksi Kanker)
# 1  Tumor Ganas (Terdeteksi Kanker)
# 2  Tumor Ganas (Terdeteksi Kanker)
# 3  Tumor Ganas (Terdeteksi Kanker)
# 4  Tumor Ganas (Terdeteksi Kanker)

# %%
df.to_excel("df_diagnosis_fix.xlsx")
# Out:
# <ipython-input-8-f75201e94287>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   df.to_excel("df_diagnosis_fix.xlsx")

# %%
M_data = df[df['diagnosis'] == 'M']
M_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 563    926125         M        20.92         25.09          143.00     1347.0
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
#
# ...

# %%
B_data = df[df['diagnosis'] == 'B']
B_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B       14.590         22.68           96.39      657.1
# 559    925291         B       11.510         23.93           74.52      403.5
# 560    925292         B       14.050         27.15           91.38      600.4
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# M_data.to_excel("M_data.xlsx")

# %%
M_data = M_data['diagnosis']
M_data
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 563    M
# 564    M
# 565    M
# 566    M
# 567    M
# Name: diagnosis, Length: 212, dtype: object

# %%
B_data = B_data['diagnosis']
B_data
# Out:
# 19     B
# 20     B
# 21     B
# 37     B
# 46     B
#       ..
# 558    B
# 559    B
# 560    B
# 561    B
# 568    B
# Name: diagnosis, Length: 357, dtype: object

# %%
M_df = pd.DataFrame(data=M_data)

# %%
M_df
# Out:
#     diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 563         M
# 564         M
# 565         M
# 566         M
# 567         M
#
# [212 rows x 1 columns]

# %%
B_df = pd.DataFrame(data=B_data)

# %%
B_df
# Out:
#     diagnosis
# 19          B
# 20          B
# 21          B
# 37          B
# 46          B
# ..        ...
# 558         B
# 559         B
# 560         B
# 561         B
# 568         B
#
# [357 rows x 1 columns]

# %%
M_df.to_excel("M_df.xlsx")
B_df.to_excel("M_df.xlsx")
# Out:
# <ipython-input-17-e6957519d355>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   M_df.to_excel("M_df.xlsx")
# <ipython-input-17-e6957519d355>:2: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   B_df.to_excel("M_df.xlsx")
